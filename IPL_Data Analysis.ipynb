# %% [markdown]
#  # IPL 2025 Batting Performance Analysis

# %% [markdown]
# # Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the Dataset and Explore It

# %%
df = pd.read_csv('IPL2025Batters.csv')
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
df.head(2)
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38

# %% [markdown]
# ## Understand Basic Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
df.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Team', 'Runs', 'Matches', 'Inn', 'No', 'HS', 'AVG',
#        'BF', 'SR', '100s', '50s', '4s', '6s'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Player Name    0
# Team           0
# Runs           0
# Matches        0
# Inn            0
# No             0
# HS             0
# AVG            0
# BF             0
# SR             0
# 100s           0
# 50s            0
# 4s             0
# 6s             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df.head(2)
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38

# %%
top_scores = df.sort_values(by='Runs',ascending=False).head(10)
top_scores
# Out:
#          Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5       Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6   Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 7  Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 8          K L Rahul    DC   539       13   13   3  112*  53.90  360  149.72
# 9        Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# ...

# %% [markdown]
# # Top 10 Run Scorers

# %%
# top_scores.plot(x='Player Name',y='Runs',kind='bar',color='orange',title='Top 10 Run Scores');
plt.figure(figsize=(10, 6))

sns.barplot(x='Player Name',y='Runs',data = top_scores ,palette='Set1')
plt.title('Top 10 Run Scores',fontsize=14)
plt.ylabel('Runs')
plt.xlabel('Player Name')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top Strike Rates

# %%
df_filtered = df[df['SR']>100]
df_filtered
# Out:
#            Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0        Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1    Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 2          Virat Kohli   RCB   657       15   15   3   73*  54.75  454
# 3         Shubman Gill    GT   650       15   15   2   93*  50.00  417
# 4       Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# ..                 ...   ...   ...      ...  ...  ..   ...    ...  ...
# 124      Kwena Maphaka    RR     8        2    1   1    8*      -    2
# 125     Raj Angad Bawa    MI     8        3    1   1    8*      -    4
# 129         Akash Deep   LSG     6        6    2   1    6*   6.00    2
# 130     Sandeep Sharma    RR     6       10    1   1    6*      -    5
# 137    Lockie Ferguson  PBKS     4        4    1   1    4*      -    1
#
#          SR  100s  50s  4s  6s
# 0    156.17     1    6  88  21
# 1    167.91     0    5  69  38
# ...

# %%
Top_Sr = df_filtered.sort_values(by='SR',ascending=False).head(10)
Top_Sr
# Out:
#              Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 137      Lockie Ferguson  PBKS     4        4    1   1   4*      -    1
# 124        Kwena Maphaka    RR     8        2    1   1   8*      -    2
# 129           Akash Deep   LSG     6        6    2   1   6*   6.00    2
# 84      Romario Shepherd   RCB    70        8    3   1  53*  35.00   24
# 109        Jamie Overton   CSK    15        3    2   2  11*      -    7
# 85           Urvil Patel   CSK    68        3    3   0   37  22.67   32
# 39   Vaibhav Suryavanshi    RR   252        7    7   0  101  36.00  122
# 105         Kusal Mendis    GT    20        1    1   0   20  20.00   10
# 125       Raj Angad Bawa    MI     8        3    1   1   8*      -    4
# 10       Nicholas Pooran   LSG   524       14   14   2  87*  43.67  267
#
#          SR  100s  50s  4s  6s
# 137  400.00     0    0   1   0
# 124  400.00     0    0   2   0
# 129  300.00     0    0   0   1
# 84   291.66     0    1   5   7
# ...

# %%
plt.figure(figsize=(10, 6))

sns.barplot(x='Player Name',y='SR',data = Top_Sr,palette='Set1')
plt.title('Top 10 Strike Rate',fontsize=14)
plt.ylabel('Strike Rate')
plt.xlabel('Player Name')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Highest Batting Score

# %%
Top_Hs = df_filtered.sort_values(by='HS',ascending=False).head(10)
Top_Hs
# Out:
#            Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 64     Quinton De Kock   KKR   152        8    8   1  97*  21.71  117  129.91
# 5         Shreyas Iyer  PBKS   604       17   17   5  97*  50.33  345  175.07
# 9          Jos Buttler    GT   538       14   13   4  97*  59.78  330  163.03
# 17         Riyan Parag    RR   393       14   14   2   95  32.75  236  166.52
# 43        Ayush Mhatre   CSK   240        7    7   0   94  34.29  127  188.97
# 3         Shubman Gill    GT   650       15   15   2  93*  50.00  417  155.87
# 7    Prabhsimran Singh  PBKS   549       17   17   0   91  32.29  342  160.52
# 121      Shahbaz Ahmed   LSG     9        3    1   0    9   9.00    8  112.50
# 53          Karun Nair    DC   198        8    8   0   89  24.75  115  172.17
# 71          Sam Curran   CSK   114        5    5   0   88  22.80   84  135.71
#
#      100s  50s  4s  6s
# 64      0    1   9  11
# 5       0    6  43  39
# 9       0    5  52  24
# ...

# %%
plt.figure(figsize=(10,6))

plt.title('Top 10 Highest Score')
sns.barplot(x='Player Name',y='HS',data=Top_Hs,palette='Set1')

plt.xlabel('Player Name')
plt.ylabel('Highest Score')
plt.xticks(rotation=90)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Highest Batting Averages Score

# %%
Top_AVG = df_filtered.sort_values(by='AVG',ascending=False).head(10)
Top_AVG
# Out:
#               Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 95        Ramandeep Singh  KKR    47       11    7   2   22   9.40   35
# 91   Jake Fraser - McGurk   DC    55        6    6   0   38   9.17   52
# 121         Shahbaz Ahmed  LSG     9        3    1   0    9   9.00    8
# 120         Kagiso Rabada   GT     9        4    2   1   7*   9.00    8
# 108        Gerald Coetzee   GT    17        4    2   0   12   8.50   11
# 99    Ravichandran Ashwin  CSK    33        9    4   0   13   8.25   30
# 96            Rashid Khan   GT    40       15    8   3   12   8.00   28
# 110         Anshul Kamboj  CSK    14        8    5   3   5*   7.00   12
# 1       Surya Kumar Yadav   MI   717       16   16   5  73*  65.18  427
# 56              Tim David  RCB   187       12    9   6  50*  62.33  101
#
#          SR  100s  50s  4s  6s
# 95   134.28     0    0   1   4
# 91   105.76     0    0   7   2
# 121  112.50     0    0   1   0
# 120  112.50     0    0   0   1
# ...

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Player Name',y='AVG',data=Top_AVG,palette='Set1')
plt.title('TOP 10 Average Rate',fontsize=14)
plt.xlabel('Player_Name')
plt.ylabel('Average')
plt.xticks(rotation=90)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Distribution of Batting Average (Histogram)

# %%
sns.histplot(df['AVG'],bins=20,kde=True,color='skyblue')
plt.title('Distribution of Batting Average')
plt.xlabel('Average')
plt.ylabel('Number of plyers')
plt.show()

# %% [markdown]
# #  Scatter Plot: AVG vs SR

# %%
sns.scatterplot(x='AVG', y='SR', hue='Team', data=df, palette='tab10')
plt.title('Batting Average vs Strike Rate')
plt.xlabel('Average')
plt.ylabel('Strike Rate')
plt.show()

# %% [markdown]
# # Boundary Hitters (Most 4s and 6s)

# %%
df.head(2)

# %%
df['Total Boundaries'] = df['4s']+df['6s']

# %%
Total_boun = df.sort_values(by='Total Boundaries',ascending=False).head(10)
Total_boun

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Player Name',y='Total Boundaries',data=Total_boun, palette='Set1')
plt.title('Top 10 Boundaries',fontsize=14)
plt.xlabel('Player Name')
plt.ylabel('Total Boundaries')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #  Best Teams by Total Runs

# %%
df.head(2)

# %%
Top_Team = df.groupby(['Team'])['Runs'].sum().sort_values(ascending=False).head(10).reset_index()
Top_Team

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Team',y='Runs',data=Top_Team,palette='Set1')
plt.title('Top 10 teams Highest Score',fontsize=14)
plt.xlabel('Teams')
plt.ylabel('Runs')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Team-wise Average Strike Rate

# %%
df.head(2)

# %%
Team_sr = df.groupby(['Team'])['SR'].mean().sort_values(ascending=False).reset_index()
Team_sr

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Team',y='SR',data=Team_sr,palette='Set1')
plt.title('Team wise Average Strike',fontsize=14)
plt.xlabel('Team')
plt.ylabel('Strike Rate')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top 10 Players with Most Centuries (100s)

# %%
df.head(2)

# %%
Top_100s = df[df['100s']>0].sort_values(by='100s',ascending=False).head(10)
Top_100s

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Player Name',y='100s',data=Top_100s,palette='Set1')
plt.title('Top 10 Players with Most Century')
plt.xlabel('Player')
plt.ylabel('100s')
plt.xticks(rotation=90)
plt.show()

# %%
df.head(2)

# %%
df['Run_per_match'] = df['Runs']/df['Matches']
df

# %%
Top_RPM = df.sort_values(by = 'Run_per_match',ascending=False).head(10)
Top_RPM

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Player Name',y='Run_per_match',data=Top_RPM,palette='Set1')
plt.title('Top 10 Players by Runs per Match',fontsize=14)
plt.xlabel('Player Name')
plt.ylabel('Run_per_match')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Runs Per Ball

# %%
df.head(2)

# %%
df['run_per_balls'] = df['Runs']/df['BF']

# %%
df.head(2)

# %%
Top_RPB = df.sort_values(by ='run_per_balls',ascending=False).head(10)
Top_RPB

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Player Name',y='run_per_balls',data=Top_RPB,palette='Set1')
plt.title('Run_per_Balls',fontsize=14)
plt.xlabel('player Name')
plt.ylabel('Run_per_Balls')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Consistency Score

# %%
df['consistency'] = df['50s'] +df['100s'] / df['Inn']
df['consistency']

# %%
df.head(2)

# %%
con = df.sort_values(by='consistency',ascending=False).head(10)
con

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Player Name',y='consistency',data=con,palette='Set1')
plt.title('Consistency Score',fontsize=14)
plt.xlabel('Player Name')
plt.ylabel('Consistency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Team Strength Index (Batting)

# %%
team_strength = df.groupby(['Team']).agg({'Runs':'sum','SR':'mean','4s':'sum','6s':'sum'}).reset_index()
team_strength

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Team',y='Runs',data=team_strength,palette='Set1')
plt.title('Team Strength Index', fontsize=14)
plt.xlabel('Team Name')
plt.ylabel('Runs')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7),dpi=500)

sns.barplot(x='Team',y='SR',data=team_strength,palette='Set1')
plt.title('Team Strength Index', fontsize=14)
plt.xlabel('Team Name')
plt.ylabel('Runs')
plt.xticks(rotation=90)
plt.show()
